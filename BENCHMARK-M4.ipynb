# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
# Importo il file csv
file_path = "C:/Users/madda/anaconda3/csv_import/dataset.csv"
strutture = pd.read_csv (file_path, delimiter=",", encoding="latin1", low_memory=False)

# Verifico le dimensioni del dataset
dimensioni = strutture.shape
print("Dimensioni del dataset:", dimensioni)
# Out:
# Dimensioni del dataset: (376967, 67)

# %%
# Visualizzo in tabella
strutture
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-08          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-09          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 376962      ZWE    Africa     Zimbabwe  2024-01-31     266265.0        0.0
# 376963      ZWE    Africa     Zimbabwe  2024-02-01     266265.0        0.0
# 376964      ZWE    Africa     Zimbabwe  2024-02-02     266265.0        0.0
# 376965      ZWE    Africa     Zimbabwe  2024-02-03     266265.0        0.0
# 376966      ZWE    Africa     Zimbabwe  2024-02-04     266265.0        0.0
#
# ...

# %%
# Verifico le diciture presenti nell'intestazione
diciture_intestazione = strutture.columns.tolist()

print("Diciture presenti nell'intestazione:", diciture_intestazione)
# Out:
# Diciture presenti nell'intestazione: ['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases', 'new_cases_smoothed', 'total_deaths', 'new_deaths', 'new_deaths_smoothed', 'total_cases_per_million', 'new_cases_per_million', 'new_cases_smoothed_per_million', 'total_deaths_per_million', 'new_deaths_per_million', 'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients', 'icu_patients_per_million', 'hosp_patients', 'hosp_patients_per_million', 'weekly_icu_admissions', 'weekly_icu_admissions_per_million', 'weekly_hosp_admissions', 'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated', 'total_boosters', 'new_vaccinations', 'new_vaccinations_smoothed', 'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred', 'people
# ...

# %%
diciture_intestazione
# Out:
# ['iso_code',
#  'continent',
#  'location',
#  'date',
#  'total_cases',
#  'new_cases',
#  'new_cases_smoothed',
#  'total_deaths',
#  'new_deaths',
#  'new_deaths_smoothed',
#  'total_cases_per_million',
#  'new_cases_per_million',
#  'new_cases_smoothed_per_million',
#  'total_deaths_per_million',
#  'new_deaths_per_million',
#  'new_deaths_smoothed_per_million',
#  'reproduction_rate',
#  'icu_patients',
#  'icu_patients_per_million',
#  'hosp_patients',
#  'hosp_patients_per_million',
#  'weekly_icu_admissions',
#  'weekly_icu_admissions_per_million',
#  'weekly_hosp_admissions',
#  'weekly_hosp_admissions_per_million',
#  'total_tests',
#  'new_tests',
#  'total_tests_per_thousand',
#  'new_tests_per_thousand',
#  'new_tests_smoothed',
#  'new_tests_smoothed_per_thousand',
#  'positive_rate',
#  'tests_per_case',
#  'tests_units',
#  'total_vaccinations',
#  'people_vaccinated',
#  'people_fully_vaccinated',
#  'total_boosters',
#  'new_vaccinations',
# ...

# %%
#Visualizzo le prime 5 righe con le rispettive colonne in formato tabella
strutture.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
strutture.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  3.380850e+05  3.661160e+05        3.648860e+05  3.161130e+05
# mean   7.202762e+06  8.965883e+03        8.995879e+03  8.890612e+04
# std    4.314687e+07  2.430048e+05        9.162390e+04  4.522645e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    9.106000e+03  0.000000e+00        1.430000e-01  1.330000e+02
# 50%    7.676400e+04  0.000000e+00        1.957100e+01  1.369000e+03
# 75%    8.320440e+05  0.000000e+00        4.332860e+02  1.225000e+04
# max    7.744934e+08  4.423623e+07        6.319461e+06  7.026534e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  366124.000000        364894.000000            338085.000000
# mean       79.760174            80.028251            109569.889332
# std      1444.166144           541.716519            157821.149563
# min         0.000000             0.000000                 0.000000
# ...

# %%
# Per ogni continente trovare il numero di casi totali avvenuti in quello stesso continente

# Filtro il dataset per le righe con valori non nulli nella colonna "continent"
continent_cases = strutture[strutture['continent'].notnull()]

# Raggruppo e sommo i nuovi casi per ogni continente (delta giornaliero)
total_new_cases_per_continent = strutture.groupby('continent')['new_cases'].sum()

print("Nuovi casi totali per continente:")
print(total_new_cases_per_continent)
# Out:
# Nuovi casi totali per continente:
# continent
# Africa            13136517.0
# Asia             301391174.0
# Europe           252013370.0
# North America    124526003.0
# Oceania           14741735.0
# South America     68752780.0
# Name: new_cases, dtype: float64

# %%
# Eseguo la consegna calcolando anche le locazioni senza indicazione di continente

def confronta_casi_totali(dataset, continente1, continente2):
    
    # Estraggo i casi totali per i due continenti specificati
    casi_continente1 = dataset[dataset['continent'] == continente1]['new_cases']
    casi_continente2 = dataset[dataset['continent'] == continente2]['new_cases']
    
    # Calcolo la somma totale dei casi
    casi_totali = dataset['new_cases'].sum()
    
    # Calcolo i descrittori statistici per il continente 1
    min_casi_continente1 = casi_continente1.min()
    max_casi_continente1 = casi_continente1.max()
    mean_casi_continente1 = casi_continente1.mean()
    perc_casi_continente1 = (casi_continente1.sum() / casi_totali) * 100
    
    # Calcolo i descrittori statistici per il continente 2
    min_casi_continente2 = casi_continente2.min()
    max_casi_continente2 = casi_continente2.max()
    mean_casi_continente2 = casi_continente2.mean()
    perc_casi_continente2 = (casi_continente2.sum() / casi_totali) * 100
    
    # Creo un dizionario per i risultati
    risultati = {
        'Continente 1': continente1,
        'Minimo Casi Continente 1': min_casi_continente1,
        'Massimo Casi Continente 1': max_casi_continente1,
        'Media Casi Continente 1': mean_casi_continente1,
        'Percentuale Casi Continente 1': perc_casi_continente1,
        'Continente 2': continente2,
        'Minimo Casi Continente 2': min_casi_continente2,
        'Massimo Casi Continente 2': max_casi_continente2,
        'Media Casi Continente 2': mean_casi_continente2,
        'Percentuale Casi Continente 2': perc_casi_continente2
    }
    
    return risultati

# Chiedo all'utente i nomi dei continenti di interesse
continente1 = input("Inserisci il nome del primo continente,a scelta tra i seguenti Africa, Asia, Europe, North America, Oceania, South America: ")
continente2 = input("Inserisci il nome del secondo continente,a scelta tra i seguenti Africa, Asia, Europe, North America, Oceania, South America: ")

risultati = confronta_casi_totali(strutture, continente1, continente2)
print(risultati)
# Out:
# Inserisci il nome del primo continente,a scelta tra i seguenti Africa, Asia, Europe, North America, Oceania, South America:  Europe
# Inserisci il nome del secondo continente,a scelta tra i seguenti Africa, Asia, Europe, North America, Oceania, South America:  Oceania
# {'Continente 1': 'Europe', 'Minimo Casi Continente 1': 0.0, 'Massimo Casi Continente 1': 2417043.0, 'Media Casi Continente 1': 3339.960373207517, 'Percentuale Casi Continente 1': 7.677358236403552, 'Continente 2': 'Oceania', 'Minimo Casi Continente 2': 0.0, 'Massimo Casi Continente 2': 588813.0, 'Media Casi Continente 2': 411.72280407764276, 'Percentuale Casi Continente 2': 0.4490935565090396}

# %%
# Per ogni continente trovare il numero di vaccini totali eseguiti
#N.B. Per "vaccinazioni totali" si è inteso i vaccini eseguiti, NON le persone vaccinate (per il Covid-19 sono stati previsti almeno 3 richiami a persona)

# Filtro il dataset per le righe con valori non nulli nella colonna "continent"
continent_cases = strutture[strutture['continent'].notnull()]

# Raggruppo e sommo i vaccini per ogni continente (delta giornaliero)
total_vaccini_per_continent = strutture.groupby('continent')['new_vaccinations'].sum()

print("Totale vaccini per continente:")
print(total_vaccini_per_continent)
# Out:
# Totale vaccini per continente:
# continent
# Africa           1.173671e+08
# Asia             7.550420e+09
# Europe           1.267550e+09
# North America    1.003604e+09
# Oceania          7.481582e+07
# South America    8.463748e+08
# Name: new_vaccinations, dtype: float64

# %%
import humanize

# Converto il risultato in formato più leggibile
total_vaccini_per_continent_leggibile = total_vaccini_per_continent.apply(humanize.intword)

print("Totale vaccini per continente:")
print(total_vaccini_per_continent_leggibile)
# Out:
# Totale vaccini per continente:
# continent
# Africa           117.4 million
# Asia               7.6 billion
# Europe             1.3 billion
# North America      1.0 billion
# Oceania           74.8 million
# South America    846.4 million
# Name: new_vaccinations, dtype: object

# %%
# Eseguo la consegna calcolando anche le locazioni senza indicazione di continente

def confronta_vaccini_totali(dataset, continente1, continente2):
    
    # Estraggo i vaccini totali per i due continenti specificati
    vaccini_continente1 = dataset[dataset['continent'] == continente1]['new_vaccinations']
    vaccini_continente2 = dataset[dataset['continent'] == continente2]['new_vaccinations']
    
    # Calcolo la somma totale dei vaccini
    vaccini_totali = dataset['new_vaccinations'].sum()
    
    # Calcolo i descrittori statistici per il continente 1
    min_vaccini_continente1 = vaccini_continente1.min()
    max_vaccini_continente1 = vaccini_continente1.max()
    mean_vaccini_continente1 = vaccini_continente1.mean()
    perc_vaccini_continente1 = (vaccini_continente1.sum() / vaccini_totali) * 100
    
    # Calcolo i descrittori statistici per il continente 2
    min_vaccini_continente2 = vaccini_continente2.min()
    max_vaccini_continente2 = vaccini_continente2.max()
    mean_vaccini_continente2 = vaccini_continente2.mean()
    perc_vaccini_continente2 = (vaccini_continente2.sum() / vaccini_totali) * 100
    
    # Converto i valori in formato leggibile
    min_vaccini_continente1 = humanize.intcomma(min_vaccini_continente1)
    max_vaccini_continente1 = humanize.intcomma(max_vaccini_continente1)
    mean_vaccini_continente1 = humanize.intcomma(int(mean_vaccini_continente1))
    perc_vaccini_continente1 = humanize.intword(perc_vaccini_continente1)
    min_vaccini_continente2 = humanize.intcomma(min_vaccini_continente2)
    max_vaccini_continente2 = humanize.intcomma(max_vaccini_continente2)
    mean_vaccini_continente2 = humanize.intcomma(int(mean_vaccini_continente2))
    perc_vaccini_continente2 = humanize.intword(perc_vaccini_continente2)
    
    # Creo un dizionario per i risultati
    risultati = {
        'Continente 1': continente1,
        'Minimo Vaccini eseguiti in una giornata Continente 1': min_vaccini_continente1,
        'Massimo Vaccini eseguiti in una giornata Continente 1': max_vaccini_continente1,
        'Media Vaccini eseguiti in una giornata Continente 1': mean_vaccini_continente1,
        'Percentuale Vaccini in Continente 1': perc_vaccini_continente1,
        'Continente 2': continente2,
        'Minimo Vaccini eseguiti in una giornata Continente 2': min_vaccini_continente2,
        'Massimo Vaccini eseguiti in una giornata Continente 2': max_vaccini_continente2,
        'Media Vaccini eseguiti in una giornata Continente 2': mean_vaccini_continente2,
        'Percentuale Vaccini in Continente 2': perc_vaccini_continente2
    }
    
    return risultati

# Scelgo i nomi dei continenti di interesse
continente1 = input("Inserisci il nome del primo continente, a scelta tra i seguenti Africa, Asia, Europa, Nord America, Oceania, Sud America: ")
continente2 = input("Inserisci il nome del secondo continente, a scelta tra i seguenti Africa, Asia, Europa, Nord America, Oceania, Sud America: ")

risultati = confronta_vaccini_totali(strutture, continente1, continente2)
print(risultati)
# Out:
# Inserisci il nome del primo continente, a scelta tra i seguenti Africa, Asia, Europa, Nord America, Oceania, Sud America:  Asia
# Inserisci il nome del secondo continente, a scelta tra i seguenti Africa, Asia, Europa, Nord America, Oceania, Sud America:  Europe
# {'Continente 1': 'Asia', 'Minimo Vaccini eseguiti in una giornata Continente 1': '0.0', 'Massimo Vaccini eseguiti in una giornata Continente 1': '24,741,000.0', 'Media Vaccini eseguiti in una giornata Continente 1': '484,373', 'Percentuale Vaccini in Continente 1': '14', 'Continente 2': 'Europe', 'Minimo Vaccini eseguiti in una giornata Continente 2': '0.0', 'Massimo Vaccini eseguiti in una giornata Continente 2': '2,389,472.0', 'Media Vaccini eseguiti in una giornata Continente 2': '55,146', 'Percentuale Vaccini in Continente 2': '2'}

# %%
# Eseguo la consegna calcolando anche le locazioni senza indicazione di continente

def confronta_vaccini_totali(dataset, continente1, continente2):
    
    # Estraggo i vaccini totali per i due continenti specificati
    vaccini_continente1 = dataset[dataset['continent'] == continente1]['new_vaccinations']
    vaccini_continente2 = dataset[dataset['continent'] == continente2]['new_vaccinations']
    
    # Calcolo la somma totale dei vaccini
    vaccini_totali = dataset['new_vaccinations'].sum()
    
    # Calcolo i descrittori statistici per il continente 1
    min_vaccini_continente1 = vaccini_continente1.min()
    max_vaccini_continente1 = vaccini_continente1.max()
    mean_vaccini_continente1 = vaccini_continente1.mean()
    perc_vaccini_continente1 = (vaccini_continente1.sum() / vaccini_totali) * 100
    
    # Calcolo i descrittori statistici per il continente 2
    min_vaccini_continente2 = vaccini_continente2.min()
    max_vaccini_continente2 = vaccini_continente2.max()
    mean_vaccini_continente2 = vaccini_continente2.mean()
    perc_vaccini_continente2 = (vaccini_continente2.sum() / vaccini_totali) * 100
    
    # Converto i valori in formato leggibile
    min_vaccini_continente1 = humanize.intcomma(min_vaccini_continente1)
    max_vaccini_continente1 = humanize.intcomma(max_vaccini_continente1)
    mean_vaccini_continente1 = humanize.intcomma(int(mean_vaccini_continente1))
    perc_vaccini_continente1 = humanize.intword(perc_vaccini_continente1)
    min_vaccini_continente2 = humanize.intcomma(min_vaccini_continente2)
    max_vaccini_continente2 = humanize.intcomma(max_vaccini_continente2)
    mean_vaccini_continente2 = humanize.intcomma(int(mean_vaccini_continente2))
    perc_vaccini_continente2 = humanize.intword(perc_vaccini_continente2)
    
    # Creo un dizionario per i risultati
    risultati = {
        'Continente 1': continente1,
        'Minimo Vaccini eseguiti in una giornata Continente 1': min_vaccini_continente1,
        'Massimo Vaccini eseguiti in una giornata Continente 1': max_vaccini_continente1,
        'Media Vaccini eseguiti in una giornata Continente 1': mean_vaccini_continente1,
        'Percentuale Vaccini in Continente 1': perc_vaccini_continente1,
        'Continente 2': continente2,
        'Minimo Vaccini eseguiti in una giornata Continente 2': min_vaccini_continente2,
        'Massimo Vaccini eseguiti in una giornata Continente 2': max_vaccini_continente2,
        'Media Vaccini eseguiti in una giornata Continente 2': mean_vaccini_continente2,
        'Percentuale Vaccini in Continente 2': perc_vaccini_continente2
    }
    
    return risultati

# Scelgo i nomi dei continenti di interesse
continente1 = input("Inserisci il nome del primo continente, a scelta tra i seguenti Africa, Asia, Europa, Nord America, Oceania, Sud America: ")
continente2 = input("Inserisci il nome del secondo continente, a scelta tra i seguenti Africa, Asia, Europa, Nord America, Oceania, Sud America: ")

risultati = confronta_vaccini_totali(strutture, continente1, continente2)
print(risultati)
# Out:
# Inserisci il nome del primo continente, a scelta tra i seguenti Africa, Asia, Europa, Nord America, Oceania, Sud America:  Asia
# Inserisci il nome del secondo continente, a scelta tra i seguenti Africa, Asia, Europa, Nord America, Oceania, Sud America:  Europe
# {'Continente 1': 'Asia', 'Minimo Vaccini eseguiti in una giornata Continente 1': '0.0', 'Massimo Vaccini eseguiti in una giornata Continente 1': '24,741,000.0', 'Media Vaccini eseguiti in una giornata Continente 1': '484,373', 'Percentuale Vaccini in Continente 1': '14', 'Continente 2': 'Europe', 'Minimo Vaccini eseguiti in una giornata Continente 2': '0.0', 'Massimo Vaccini eseguiti in una giornata Continente 2': '2,389,472.0', 'Media Vaccini eseguiti in una giornata Continente 2': '55,146', 'Percentuale Vaccini in Continente 2': '2'}

# %%
def confronta_casi_totali_vaccini(dataset, continente1, continente2, continente3):
    
    # Funzione per rendere i valori leggibili
    def leggibili(valore):
        if isinstance(valore, float):
            return humanize.intcomma(int(valore))
        elif isinstance(valore, int):
            return humanize.intword(valore)
        else:
            return valore
    
    # Estraggo i casi totali per i tre continenti specificati
    casi_continente1 = dataset[dataset['continent'] == continente1]['new_cases']
    casi_continente2 = dataset[dataset['continent'] == continente2]['new_cases']
    casi_continente3 = dataset[dataset['continent'] == continente3]['new_cases']
    
    # Calcolo la somma totale dei casi
    casi_totali = dataset['new_cases'].sum()
    
    # Calcolo i descrittori statistici per i tre continenti
    descr_casi = {}
    for continente in [continente1, continente2, continente3]:
        casi = dataset[dataset['continent'] == continente]['new_cases']
        min_casi = casi.min()
        max_casi = casi.max()
        mean_casi = casi.mean()
        perc_casi = (casi.sum() / casi_totali) * 100
        
        # Rendo i valori leggibili
        descr_casi[continente] = {
            'Minimo Casi': leggibili(min_casi),
            'Massimo Casi': leggibili(max_casi),
            'Media Casi': leggibili(mean_casi),
            'Percentuale Casi': leggibili(perc_casi)
        }
    
    return descr_casi

def confronta_vaccini_totali_vaccini(dataset, continente1, continente2, continente3):
    
    # Funzione per rendere i valori leggibili
    def leggibili(valore):
        if isinstance(valore, float):
            return humanize.intcomma(int(valore))
        elif isinstance(valore, int):
            return humanize.intword(valore)
        else:
            return valore
    
    # Estraggo i vaccini totali per i tre continenti specificati
    vaccini_continente1 = dataset[dataset['continent'] == continente1]['new_vaccinations']
    vaccini_continente2 = dataset[dataset['continent'] == continente2]['new_vaccinations']
    vaccini_continente3 = dataset[dataset['continent'] == continente3]['new_vaccinations']
    
    # Calcolo la somma totale dei vaccini
    vaccini_totali = dataset['new_vaccinations'].sum()
    
    # Calcolo i descrittori statistici per i tre continenti
    descr_vaccini = {}
    for continente in [continente1, continente2, continente3]:
        vaccini = dataset[dataset['continent'] == continente]['new_vaccinations']
        min_vaccini = vaccini.min()
        max_vaccini = vaccini.max()
        mean_vaccini = vaccini.mean()
        perc_vaccini = (vaccini.sum() / vaccini_totali) * 100
        
        # Rendo i valori leggibili
        descr_vaccini[continente] = {
            'Minimo Vaccini eseguiti': leggibili(min_vaccini),
            'Massimo Vaccini eseguiti': leggibili(max_vaccini),
            'Media Vaccini eseguiti': leggibili(mean_vaccini),
            'Percentuale Vaccini': leggibili(perc_vaccini)
        }
    
    return descr_vaccini

# Scelgo i nomi dei continenti di interesse
continente1 = input("Inserisci il nome del primo continente,a scelta tra i seguenti Africa, Asia, Europe, North America, Oceania, South America: ")
continente2 = input("Inserisci il nome del secondo continente,a scelta tra i seguenti Africa, Asia, Europe, North America, Oceania, South America: ")
continente3 = input("Inserisci il nome del terzo continente,a scelta tra i seguenti Africa, Asia, Europe, North America, Oceania, South America: ")

risultati_casi = confronta_casi_totali_vaccini(strutture, continente1, continente2, continente3)
print("Risultati Casi:")
print(risultati_casi)

risultati_vaccini = confronta_vaccini_totali_vaccini(strutture, continente1, continente2, continente3)
print("\nRisultati Vaccini:")
print(risultati_vaccini)
# Out:
# Inserisci il nome del primo continente,a scelta tra i seguenti Africa, Asia, Europe, North America, Oceania, South America:  Oceania
# Inserisci il nome del secondo continente,a scelta tra i seguenti Africa, Asia, Europe, North America, Oceania, South America:  Europe
# Inserisci il nome del terzo continente,a scelta tra i seguenti Africa, Asia, Europe, North America, Oceania, South America:  South America
# Risultati Casi:
# {'Oceania': {'Minimo Casi': '0', 'Massimo Casi': '588,813', 'Media Casi': '411', 'Percentuale Casi': '0'}, 'Europe': {'Minimo Casi': '0', 'Massimo Casi': '2,417,043', 'Media Casi': '3,339', 'Percentuale Casi': '7'}, 'South America': {'Minimo Casi': '0', 'Massimo Casi': '1,283,024', 'Media Casi': '3,291', 'Percentuale Casi': '2'}}
#
# Risultati Vaccini:
# ...

# %%
def confronta_casi_totali_vaccini(dataset, continente1, continente2, continente3):
    
    # Funzione per rendere i valori leggibili
    def leggibili(valore):
        if isinstance(valore, float):
            return humanize.intcomma(int(valore))
        elif isinstance(valore, int):
            return humanize.intword(valore)
        else:
            return valore
    
    # Estraggo i casi totali per i tre continenti specificati
    casi_continente1 = dataset[dataset['continent'] == continente1]['new_cases']
    casi_continente2 = dataset[dataset['continent'] == continente2]['new_cases']
    casi_continente3 = dataset[dataset['continent'] == continente3]['new_cases']
    
    # Calcolo la somma totale dei casi
    casi_totali = dataset['new_cases'].sum()
    
    # Calcolo i descrittori statistici per i tre continenti
    descr_casi = {}
    for continente in [continente1, continente2, continente3]:
        casi = dataset[dataset['continent'] == continente]['new_cases']
        min_casi = casi.min()
        max_casi = casi.max()
        mean_casi = casi.mean()
        perc_casi = (casi.sum() / casi_totali) * 100
        
        # Rendi i valori leggibili utilizzando humanize
        descr_casi[continente] = {
            'Minimo Casi': leggibili(min_casi),
            'Massimo Casi': leggibili(max_casi),
            'Media Casi': leggibili(mean_casi),
            'Percentuale Casi': leggibili(perc_casi)
        }
    
    return descr_casi

def confronta_vaccini_totali_vaccini(dataset, continente1, continente2, continente3):
    
    # Funzione per rendere i valori leggibili utilizzando humanize
    def leggibili(valore):
        if isinstance(valore, float):
            return humanize.intcomma(int(valore))
        elif isinstance(valore, int):
            return humanize.intword(valore)
        else:
            return valore
    
    # Estraggo i vaccini totali per i tre continenti specificati
    vaccini_continente1 = dataset[dataset['continent'] == continente1]['new_vaccinations']
    vaccini_continente2 = dataset[dataset['continent'] == continente2]['new_vaccinations']
    vaccini_continente3 = dataset[dataset['continent'] == continente3]['new_vaccinations']
    
    # Calcolo la somma totale dei vaccini
    vaccini_totali = dataset['new_vaccinations'].sum()
    
    # Calcolo i descrittori statistici per i tre continenti
    descr_vaccini = {}
    for continente in [continente1, continente2, continente3]:
        vaccini = dataset[dataset['continent'] == continente]['new_vaccinations']
        min_vaccini = vaccini.min()
        max_vaccini = vaccini.max()
        mean_vaccini = vaccini.mean()
        perc_vaccini = (vaccini.sum() / vaccini_totali) * 100
        
        # Rendi i valori leggibili utilizzando humanize
        descr_vaccini[continente] = {
            'Minimo Vaccini eseguiti': leggibili(min_vaccini),
            'Massimo Vaccini eseguiti': leggibili(max_vaccini),
            'Media Vaccini eseguiti': leggibili(mean_vaccini),
            'Percentuale Vaccini': leggibili(perc_vaccini)
        }
    
    return descr_vaccini

# Scelgo i nomi dei continenti di interesse
continente1 = input("Inserisci il nome del primo continente,a scelta tra i seguenti Africa, Asia, Europe, North America, Oceania, South America: ")
continente2 = input("Inserisci il nome del secondo continente,a scelta tra i seguenti Africa, Asia, Europe, North America, Oceania, South America: ")
continente3 = input("Inserisci il nome del terzo continente,a scelta tra i seguenti Africa, Asia, Europe, North America, Oceania, South America: ")

risultati_casi = confronta_casi_totali_vaccini(strutture, continente1, continente2, continente3)
risultati_vaccini = confronta_vaccini_totali_vaccini(strutture, continente1, continente2, continente3)

# Tabelle
df_casi = pd.DataFrame(risultati_casi).transpose()
df_vaccini = pd.DataFrame(risultati_vaccini).transpose()
# Out:
# Inserisci il nome del primo continente,a scelta tra i seguenti Africa, Asia, Europe, North America, Oceania, South America:  Oceania
# Inserisci il nome del secondo continente,a scelta tra i seguenti Africa, Asia, Europe, North America, Oceania, South America:  Europe
# Inserisci il nome del terzo continente,a scelta tra i seguenti Africa, Asia, Europe, North America, Oceania, South America:  South America

# %%
print("Risultati Casi:")
df_casi
# Out:
# Risultati Casi:
#               Minimo Casi Massimo Casi Media Casi Percentuale Casi
# Oceania                 0      588,813        411                0
# Europe                  0    2,417,043      3,339                7
# South America           0    1,283,024      3,291                2

# %%
print("\nRisultati Vaccini:")
df_vaccini
# Out:
# Risultati Vaccini:
#               Minimo Vaccini eseguiti Massimo Vaccini eseguiti  \
# Oceania                             1                  351,226
# Europe                              0                2,389,472
# South America                       1                3,976,605
#
#               Media Vaccini eseguiti Percentuale Vaccini
# Oceania                       55,957                   0
# Europe                        55,146                   2
# South America                141,700                   1

# %%
import matplotlib.pyplot as plt

# Funzione per disegnare un grafico a torta
def disegna_grafico_a_torta(dati, titolo):
    etichette = dati.keys()  # Etichette
    dimensioni = dati.values()  # Dimensioni
    esplosione = (0.1, 0, 0)  # Esplosione della fetta più grande

    plt.figure(figsize=(8, 6))  # Dimensioni del grafico
    plt.pie(dimensioni, explode=esplosione, labels=etichette, autopct='%1.1f%%', startangle=140)  # Disegno del grafico a torta
    plt.axis('equal') 
    plt.title(titolo)  # Titolo del grafico
    plt.show()  # Mostra il grafico

# Calcolo delle percentuali di casi totali e vaccini totali per i tre continenti selezionati
percentuali_casi = {continente: descr['Percentuale Casi'] for continente, descr in risultati_casi.items()}
percentuali_vaccini = {continente: descr['Percentuale Vaccini'] for continente, descr in risultati_vaccini.items()}

# Disegno dei grafici a torta
disegna_grafico_a_torta(percentuali_casi, 'Percentuale di casi totali per continente')
disegna_grafico_a_torta(percentuali_vaccini, 'Percentuale di vaccini totali per continente')
